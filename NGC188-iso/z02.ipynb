# %% [markdown]
# ## NGC-188 İsochrone 9.60 - 9.65 - 0.01 ; z = 0.0188

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# verilerin dahil edilmesi
filengc = pd.read_csv("NGC188.csv") # king verisini pandas ile oku
filezams = pd.read_csv("SUNG_ZAMS.csv") # zams verisini pandas ile oku
data_ngc = pd.DataFrame(filengc) # verileri dataframe donustur
data_zams = pd.DataFrame(filezams)
data_ngc.head()
# Out:
#     No  Ref       V     BV     UB
# 0    1  240  13.029  1.035  0.682
# 1    2  240  14.930  0.783  0.305
# 2   14  240  10.761  0.618  0.113
# 3   16  240  13.002  0.472 -0.033
# 4  101  240  16.861  0.892    NaN

# %%
# pandas verilerinin numpy verilerine donusturulmesi
B_V0 = np.array(data_zams["B-V"]) # pandas verisini numpy array cevirme
U_B0 = np.array(data_zams["U-B"]) # pandas verisini numpy arary cevirme
V = np.array(data_ngc["V"])
V0 = np.array(data_zams["Mv"])

# ngc pandas verilerini numpy verisine donustur
B_V = np.array(data_ngc["BV"]) # pandas verisini numpy array cevirme
U_B = np.array(data_ngc["UB"]) # pandas verisini numpy arary cevirme

# zams pandas verilerini numpy verisine donustur
zB_V = np.array(data_zams["B-V"])
zU_B = np.array(data_zams["U-B"])

# %%
# verileri gorsellestirelim
plt.figure(figsize=(10,6))
plt.plot(B_V,V,".",label="Gözlemsel Veri")
plt.title("NGC 188 Kümesi Renk-Kadir Diagramı")
plt.xlabel("B-V")
plt.ylabel("V")

plt.gca().invert_yaxis() # y eksenini ters çevirdik
plt.legend()
#plt.savefig("ngc-dersteki.svg",format="svg")
#plt.grid()
plt.show()

# %%
iso_data = pd.read_csv("ngc-iso-z0.02.csv",dtype=np.float64)
iso_data.dropna(how="all")
# Out:
#        MH  logAge    Umag    Bmag    Vmag  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0   -0.02     9.6  22.665  19.995  18.147         NaN         NaN         NaN
# 1   -0.02     9.6  22.138  19.504  17.665         NaN         NaN         NaN
# 2   -0.02     9.6  20.925  18.489  16.692         NaN         NaN         NaN
# 3   -0.02     9.6  20.838  18.424  16.631         NaN         NaN         NaN
# 4   -0.02     9.6  19.375  17.262  15.554         NaN         NaN         NaN
# ..    ...     ...     ...     ...     ...         ...         ...         ...
# 335 -0.02     9.6   3.260   3.474   2.185         NaN         NaN         NaN
# 336 -0.02     9.6   3.484   3.678   2.361         NaN         NaN         NaN
# 337 -0.02     9.6   3.696   3.841   2.491         NaN         NaN         NaN
# 338 -0.02     9.6   3.935   4.011   2.616         NaN         NaN         NaN
# 339 -0.02     9.6  29.723  29.985  30.034         NaN         NaN         NaN
#
#      MH.1  logAge.1  ...  Bmag.1  Vmag.1  Unnamed: 13  Unnamed: 14  \
# 0   -0.02      9.65  ...  19.994  18.146          NaN          NaN
# 1   -0.02      9.65  ...  19.504  17.665          NaN          NaN
# 2   -0.02      9.65  ...  19.316  17.481          NaN          NaN
# 3   -0.02      9.65  ...  18.422  16.630          NaN          NaN
# 4   -0.02      9.65  ...  17.261  15.553          NaN          NaN
# ..    ...       ...  ...     ...     ...          ...          ...
# 335   NaN       NaN  ...     NaN     NaN          NaN          NaN
# 336   NaN       NaN  ...     NaN     NaN          NaN          NaN
# 337   NaN       NaN  ...     NaN     NaN          NaN          NaN
# 338   NaN       NaN  ...     NaN     NaN          NaN          NaN
# 339   NaN       NaN  ...     NaN     NaN          NaN          NaN
#
#      Unnamed: 15  MH.2  logAge.2  Umag.2  Bmag.2  Vmag.2
# 0            NaN -0.02       9.7  22.664  19.994  18.146
# 1            NaN -0.02       9.7  22.137  19.503  17.665
# 2            NaN -0.02       9.7  21.369  18.823  17.004
# 3            NaN -0.02       9.7  20.834  18.420  16.628
# 4            NaN -0.02       9.7  19.372  17.259  15.551
# ..           ...   ...       ...     ...     ...     ...
# 335          NaN   NaN       NaN     NaN     NaN     NaN
# 336          NaN   NaN       NaN     NaN     NaN     NaN
# 337          NaN   NaN       NaN     NaN     NaN     NaN
# 338          NaN   NaN       NaN     NaN     NaN     NaN
# 339          NaN   NaN       NaN     NaN     NaN     NaN
#
# [340 rows x 21 columns]

# %%
iso_data["Umag.1"].dropna()
# Out:
# 0      22.664
# 1      22.138
# 2      21.937
# 3      20.836
# 4      19.374
#         ...
# 321     3.130
# 322     3.235
# 323     3.308
# 324     3.398
# 325    29.723
# Name: Umag.1, Length: 326, dtype: float64

# %%
# isochrone(es yas cizgisi) = 9.6 icin degerlerin 
# numpy arraylerine cevrilmesi
Vmag96 = np.array(iso_data.Vmag.dropna()) # V
B_V096 = np.array(iso_data.Bmag.dropna()-iso_data.Vmag.dropna()) # B-V

# isochrone(es yas cizgisi) = 9.65 icin degerlerin 
# numpy arraylerine cevrilmesi
Vmag965 = np.array(iso_data["Vmag.2"].dropna())
B_V0965 = np.array(iso_data["Bmag.1"].dropna()-iso_data["Vmag.1"].dropna())

# isochrone(es yas cizgisi) = 9.7 icin degerlerin 
# numpy arraylerine cevrilmesi
Vmag97 = np.array(iso_data["Vmag.2"].dropna())
B_V097 = np.array(iso_data["Bmag.2"].dropna()-iso_data["Vmag.2"].dropna())

# %%
# verileri gorsellestirelim
plt.figure(figsize=(10, 6))
plt.plot(B_V, V, ".", label="Gözlemsel Veri")
plt.plot(B_V096[:200], Vmag96[:200], "r-", label="iso = 9.6 yas cizgisi")
# plt.plot(B_V965,V965,"b-",label="iso = 9.65 yas cizgisi")
# plt.plot(B_V97,V97,"m-",label="iso = 9.7 yas cizgisi")
plt.title("NGC 188 Kümesi Renk-Kadir Diagramı")
plt.xlabel("B-V")
plt.ylabel("V")

plt.gca().invert_yaxis()  # y eksenini ters çevirdik
plt.legend()
# plt.savefig("ngc-dersteki.svg",format="svg")
# plt.grid()
plt.show()

# %%
# verilerin kızartılmasi ve yas cizgisinin oturtulmasi

EB_V = 0.082 # ngc-188 reddening(kizarma) = 0.082 

DM = 11.81 # ngc-188 uzaklik modulu [mag] = 11.81
DM1 = 11.44

# V = Vmag + (3.1 * E(B-V)) + DM
V96 = Vmag96 + (3.1*EB_V) + DM
V965 = Vmag965 + (3.1*EB_V) + DM
V97 = Vmag97 + (3.1*EB_V) + DM

# B-V = (B-V)0 + E(B-V)
B_V96 = B_V096 + EB_V
B_V965 = B_V0965 + EB_V
B_V97 = B_V097 + EB_V

# %%
# verileri gorsellestirelim
plt.figure(figsize=(8,8))
plt.plot(B_V, V, ".", label="Gözlemsel Veri")
plt.plot(B_V96[15:200], V96[15:200], "r-",linewidth=2, label="iso = 9.6 yas cizgisi")
#plt.plot(B_V96[15:200], V96[15:200], "ro",linewidth=3, label="iso = 9.6 yas cizgisi")
plt.title("NGC 188 Kümesi Renk-Kadir Diagramı")
plt.xlabel("B-V")
plt.ylabel("V")
plt.gca().invert_yaxis()  # y eksenini ters çevirdik
plt.legend()
# plt.savefig("ngc-dersteki.svg",format="svg")
# plt.grid()
plt.show()

# %%
# verileri gorsellestirelim
plt.figure(figsize=(8,8))
plt.plot(B_V, V, ".", label="Gözlemsel Veri")
plt.plot(B_V965[15:150],V965[15:150],"b-",linewidth=2, label="iso = 9.65 yas cizgisi")
plt.title("NGC 188 Kümesi Renk-Kadir Diagramı")
plt.xlabel("B-V")
plt.ylabel("V")
plt.gca().invert_yaxis()  # y eksenini ters çevirdik
plt.legend()
# plt.savefig("ngc-dersteki.svg",format="svg")
# plt.grid()
plt.show()
